# %% [markdown]
# # Plotting assignment
#
# The goal here is to replicate the following figures as closely as possible.
# Once you have uploaded the data, only use numpy and matplotlib to create the plots (ie not pandas/xarray - we'll get to those, both of which are built on numpy and matplotlib)
#
# Run the cells called load data and use only the variables that are pre-defined for the excercise.

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line Plots

# %%
# load data
ds = xr.open_dataset('era5.nc').sel(latitude=-34,longitude=18)

# %%
# #########################################################
# #### BELOW ARE THE VARIABLES YOU SHOULD USE IN THE PLOTS!
# #### (numpy arrays) 
# #### NO XARRAY ALLOWED!
# #########################################################

time = ds.time.values

u10 = ds.u10.values
v10 = ds.v10.values


sensible_heat_flux = ds.msshf.values
latent_heat_flux = ds.mslhf.values
short_wave = ds.msnswrf.values
long_wave = ds.msnlwrf.values
net_heat_flux = (ds.msshf+ds.mslhf+ds.msnswrf+ds.msnlwrf).values

# %% [markdown]
# ![line_plot.png](attachment:aaf7909f-3b65-42bd-95ad-8f8a79df09e4.png)

# %% [markdown]
# ## Contour Plots

# %%
# load data
ds = xr.open_dataset('chla_clim.nc')

# %%
# #########################################################
# #### BELOW ARE THE VARIABLES YOU SHOULD USE IN THE PLOTS!
# #### (numpy arrays) 
# #### NO XARRAY ALLOWED!
# #########################################################

chla = ds.chlor_a
longitude = ds.lon.values
latitude = ds.lat.values

# %% [markdown]
# ![chl_contour_map.png](attachment:662b4304-9566-4178-81f8-8b6256b363c3.png)
